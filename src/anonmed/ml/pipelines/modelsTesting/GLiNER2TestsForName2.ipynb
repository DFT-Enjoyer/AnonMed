# %% [markdown]
# ## `GLiNER` Testing on `NAMES`
#
# Dataset: `wolframko/russian-pii-66k`

# %%
# !pip -q install --no-cache-dir \
    "gliner2" \
    "datasets>=2.20.0" \
    "pandas==2.2.2" \
    "matplotlib" \
    "tqdm"
